# %%
import pandas as pd

# %%
scores = pd.read_csv("../data/raw/wrestler_tournament_data_2023-2025.csv")

# %%
scores.head(20)
# Out:
#     tournamentYear wrestlerClass  wrestlerScore  wrestlerCap  wrestlerRank  \
# 0             2025            Fr           18.5          196             1
# 1             2025            Sr           14.5          148             2
# 2             2025            So           10.0          139             3
# 3             2025            Fr           21.0          117             5
# 4             2025            Jr            1.0          129             4
# 5             2025            Jr            3.0          107             6
# 6             2025            So           17.5           93             7
# 7             2025            Jr            9.0           59            11
# 8             2025            Sr            7.5           87             8
# 9             2025            Jr            5.5           78             9
# 10            2025            Jr            3.0           38            13
# ...
